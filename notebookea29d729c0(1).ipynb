# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
s=pd.read_csv("/kaggle/input/car-sales/Car_sales.csv")

# %%
s

# %%
s.shape

# %%
s.head()

# %%
s.tail()

# %%
s.info()

# %%
s.isna().sum()

# %%
s["__year_resale_value"].agg(["mean","median","max","min"])

# %%
s["__year_resale_value"].fillna(14.180000,inplace=True)

# %%
s.isna().sum()

# %%
s["Price_in_thousands"].agg(["mean","median","max","min"])

# %%
s["Price_in_thousands"].fillna(22.799000,inplace=True)

# %%
s.isna().sum()

# %%
s["Engine_size"].agg(["mean","median","max","min"])

# %%
s["Engine_size"].fillna(3.000000,inplace=True)

# %%
s.isna().sum()

# %%
s["Horsepower"].agg(["mean","median","min","max"])

# %%
s["Horsepower"].fillna(177.500000,inplace=True)

# %%
s.isna().sum()

# %%
s["Wheelbase"].agg(["mean","median","max","min"])

# %%
s["Wheelbase"].fillna(107.000000,inplace=True)

# %%
s.isna().sum()

# %%
s["Width"].agg(["mean","median","max","min"])

# %%
s["Width"].fillna(70.55,inplace=True)

# %%
s.isna().sum()

# %%
s["Length"].agg(["mean","median","min","max"])

# %%
s["Length"].fillna(187.90000,inplace=True)

# %%
s.isna().sum()

# %%
s["Fuel_capacity"].agg(["mean","median","max","min"])

# %%
s["Fuel_capacity"].fillna(17.200000,inplace=True)

# %%
s.isna().sum()

# %%
s["Curb_weight"].agg(["mean","median","min","max"])

# %%
s["Curb_weight"].fillna(3.342000,inplace=True)

# %%
s.isna().sum()

# %%
s["Fuel_efficiency"].agg(["mean","median","min","max"])

# %%
s["Fuel_efficiency"].fillna(24.000000,inplace=True)

# %%
s.isna().sum()

# %%
s["Power_perf_factor"].agg(["mean","median","min","max"])

# %%
s["Power_perf_factor"].fillna(72.030917,inplace=True)

# %%
s.isna().sum()

# %%
s.apply(lambda x:x.unique())

# %%
s.apply(lambda x:x.nunique())

# %%
s["Sales_in_thousands"]=s["Sales_in_thousands"].astype("str")

# %%
s["Sales_in_thousands"]=s["Sales_in_thousands"].str.replace(".","")

# %%
s["Sales_in_thousands"]=s["Sales_in_thousands"].astype("int")

# %%
s["__year_resale_value"]=s["__year_resale_value"].astype("str")

# %%
s["__year_resale_value"]=s["__year_resale_value"].str.replace(".","")

# %%
s["__year_resale_value"]=s["__year_resale_value"].astype("int")

# %%
s["Price_in_thousands"]=s["Price_in_thousands"].astype("str")

# %%
s["Price_in_thousands"]=s["Price_in_thousands"].str.replace(".","")

# %%
s["Price_in_thousands"]=s["Price_in_thousands"].astype("int")

# %%
s

# %%
s["Length"]=s["Length"].astype("str")

# %%
s["Length"]=s["Length"].str.replace(".","")

# %%
s["Curb_weight"]=s["Curb_weight"].astype("str")

# %%
s["Curb_weight"]=s["Curb_weight"].str.replace(".","")

# %%
s["Curb_weight"]=s["Curb_weight"].astype("int")

# %%
s["Width"]=s["Width"].astype("str")

# %%
s["Width"]=s["Width"].str.replace(".","")

# %%
s["Width"]=s["Width"].astype("int")

# %%
s["Wheelbase"]=s["Wheelbase"].astype("str")

# %%
s["Wheelbase"]=s["Wheelbase"].str.replace(".","")

# %%
s["Wheelbase"]=s["Wheelbase"].astype("int")

# %%
s["Fuel_efficiency"]=s["Fuel_efficiency"].astype("int")

# %%
s["Latest_Launch"]=pd.to_datetime(s["Latest_Launch"])

# %%
s.info()

# %%
s.head()

# %%
pd.DataFrame(s.groupby(["Manufacturer"])["Model"].value_counts())

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
s.describe().T

# %%
s

# %%
s.groupby(["Manufacturer"])["Model"].value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(20,10))
x=sns.countplot(s["Vehicle_type"])
for i in x.containers:
    x.bar_label(i)

# %%
plt.figure(figsize=(20,10))
sns.set(style="darkgrid")
x=sns.countplot(s["Manufacturer"])
plt.xticks(rotation=90)
for i in x.containers:
    x.bar_label(i)

# %%
plt.figure(figsize=(20,10))
plt.bar(s["Manufacturer"],s["Sales_in_thousands"])
plt.xticks(rotation=50);

# %%
s.groupby(s["__year_resale_value"])["Manufacturer"].value_counts()[::-1].iloc[0:10]

# %%
pd.DataFrame(s.groupby(["Vehicle_type"])["Model"].value_counts())

# %%
s.groupby(["Model"])["Fuel_efficiency"].value_counts()

# %%
s["Fuel_efficiency"].unique()

# %%
s[s["Fuel_efficiency"]>24]

# %%
sns.heatmap(s.corr(method="spearman"))

# %%
s["Engine_size"].agg(["mean","median","max","min"])

# %%
s["Engine_size"].mode()

# %%
range_e=s["Engine_size"].max()-s["Engine_size"].min()
range_e

# %%
s["Engine_size"].skew()

# %%
s["Engine_size"].kurt()

# %%
sns.distplot(s["Engine_size"])

# %%
from scipy import stats as st
import scipy.stats as st
import scipy.stats
import pylab

# %%
st.probplot(s["Engine_size"],dist="norm",plot=pylab);

# %%
ye=st.yeojohnson(s["Engine_size"]);

# %%
st.probplot(ye[0],dist="norm",plot=pylab);

# %%
ye=pd.Series(ye[0])

# %%
ye.skew()

# %%
ye.kurt()

# %%
s["Fuel_efficiency"].agg(["mean","median","max","min","std"])

# %%
range_f=s["Fuel_efficiency"].max()-s["Fuel_efficiency"].min()
range_f

# %%
s["Fuel_efficiency"].skew()

# %%
s["Fuel_efficiency"].kurt()

# %%
sns.distplot(s["Fuel_efficiency"])

# %%
st.probplot(s["Fuel_efficiency"],dist="norm",plot=pylab);

# %%
fe=st.yeojohnson(s["Fuel_efficiency"])
fe

# %%
st.probplot(fe[0],dist="norm",plot=pylab);

# %%
fe=pd.Series(fe[0])

# %%
fe.skew()

# %%
fe.kurt()

# %%
st.probplot(fe,dist="norm",plot=pylab)

# %%
p_mean=ye.mean()

# %%
sample1=ye[0:40]

# %%
s_mean=ye[0:40].mean()

# %%
no_s=40

# %%
s_std=ye[0:40].std()

# %%
p_mean=fe.mean()

# %%
sample2=fe[0:40]

# %%
s_mean=fe[0:40].mean()

# %%
no_s=40

# %%
s_std=fe[0:40].std()

# %%
value=s_mean-s_mean
value

# %%
import statsmodels
from statsmodels.stats.weightstats import ztest as zt

# %%
zval,pval=zt(sample1,sample2,value=0.0,alternative="two-sided")

# %%
alpha=0.05
if pval>alpha:
    print("accept null hypothesis")
else:
    print("reject null hypothesis")
